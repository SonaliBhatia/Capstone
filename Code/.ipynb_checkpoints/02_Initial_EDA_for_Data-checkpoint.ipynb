# %% [markdown]
# All Required Imports here

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Data source - https://www.kaggle.com/rtatman/speech-accent-archive
# http://accent.gmu.edu/

# %%
info= pd.read_csv('../Data/archive-2/speakers_all.csv')

# %%
info.head()
# Out:
#     age  age_onset              birthplace  filename native_language   sex  \
# 0  24.0       12.0         koussi, senegal   balanta         balanta  male
# 1  18.0       10.0          buea, cameroon  cameroon        cameroon  male
# 2  48.0        8.0  hong, adamawa, nigeria  fulfulde        fulfulde  male
# 3  42.0       42.0   port-au-prince, haiti   haitian         haitian  male
# 4  40.0       35.0   port-au-prince, haiti   haitian         haitian  male
#
#    speakerid   country  file_missing?  Unnamed: 9  Unnamed: 10 Unnamed: 11
# 0        788   senegal           True         NaN          NaN         NaN
# 1       1953  cameroon           True         NaN          NaN         NaN
# 2       1037   nigeria           True         NaN          NaN         NaN
# 3       1165     haiti           True         NaN          NaN         NaN
# 4       1166     haiti           True         NaN          NaN         NaN

# %%
info.drop(columns=['Unnamed: 9','Unnamed: 10','Unnamed: 11'], inplace=True)

# %%
info.isnull().sum()
# Out:
# age                0
# age_onset          0
# birthplace         4
# filename           0
# native_language    0
# sex                0
# speakerid          0
# country            5
# file_missing?      0
# dtype: int64

# %%
info[info['birthplace'].isnull()]
# Out:
#       age  age_onset birthplace      filename native_language     sex  \
# 1970  0.0        0.0        NaN  synthesized1     synthesized    male
# 1971  0.0        0.0        NaN  synthesized2     synthesized  female
# 1972  0.0        0.0        NaN  synthesized3     synthesized  female
# 1973  0.0        0.0        NaN  synthesized4     synthesized    male
#
#       speakerid country  file_missing?
# 1970        355     NaN          False
# 1971        356     NaN          False
# 1972        357     NaN          False
# 1973        358     NaN          False

# %%
info[info['country'].isnull()]
# Out:
#        age  age_onset         birthplace      filename native_language  \
# 1372  25.0       21.0  vientiane, laos,           lao2             lao
# 1970   0.0        0.0                NaN  synthesized1     synthesized
# 1971   0.0        0.0                NaN  synthesized2     synthesized
# 1972   0.0        0.0                NaN  synthesized3     synthesized
# 1973   0.0        0.0                NaN  synthesized4     synthesized
#
#          sex  speakerid country  file_missing?
# 1372  female        249     NaN          False
# 1970    male        355     NaN          False
# 1971  female        356     NaN          False
# 1972  female        357     NaN          False
# 1973    male        358     NaN          False

# %%
info['country'].value_counts()
# Out:
# usa                    393
# china                   88
# uk                      67
# india                   59
# canada                  54
#                       ...
# turkmenistan             1
# lesotho                  1
# yugoslavia               1
# montenegro               1
# antigua and barbuda      1
# Name: country, Length: 176, dtype: int64

# %% [markdown]
# # We will be using audio files from speakers from USA , China , India

# %%
new_df = info[(info['country']=='usa') | (info['country']=='china') | (info['country']=='india')]

# %%
new_df.shape
# Out:
# (540, 9)

# %%
new_df.head()
# Out:
#       age  age_onset                   birthplace  filename native_language  \
# 9    73.0        5.0       pepeekeo, hawai'i, usa   hawai'i         hawai'i
# 10   69.0        4.0          pa'ia, hawai'i, usa   hawai'i         hawai'i
# 20   25.0        5.0        jammu, kashmir, india  poonchi1         poonchi
# 104  19.0        9.0   shady grove, maryland, usa  arabic38          arabic
# 112  32.0       12.0  fort collins, colorado, usa  arabic45          arabic
#
#         sex  speakerid country  file_missing?
# 9      male       1675     usa           True
# 10   female       1676     usa           True
# 20     male        425   india           True
# 104  female       1394     usa          False
# 112  female       1456     usa          False

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 540 entries, 9 to 2170
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              540 non-null    float64
#  1   age_onset        540 non-null    float64
#  2   birthplace       540 non-null    object
#  3   filename         540 non-null    object
#  4   native_language  540 non-null    object
#  5   sex              540 non-null    object
#  6   speakerid        540 non-null    int64
#  7   country          540 non-null    object
#  8   file_missing?    540 non-null    bool
# dtypes: bool(1), float64(2), int64(1), object(5)
# memory usage: 38.5+ KB

# %%
new_df['file_missing?'].value_counts()
# Out:
# False    537
# True       3
# Name: file_missing?, dtype: int64

# %%
new_df=new_df[new_df['file_missing?']==False]

# %%
new_df.shape
# Out:
# (537, 9)

# %%
#Read from other files created and create and convert into single dataframe to concatenate all
df1 = pd.read_csv('../Data/all_speakers_china1.csv')
df2 = pd.read_csv('../Data/all_speakers_china2.csv')
df3 = pd.read_csv('../Data/all_speakers_india1.csv')
df4 = pd.read_csv('../Data/all_speakers_india2.csv')
df5 = pd.read_csv('../Data/all_speakers_india3.csv')
df6 = pd.read_csv('../Data/all_speakers_india4.csv')
df7 = pd.read_csv('../Data/all_speakers_india5.csv')
df8 = pd.read_csv('../Data/all_speakers_india6.csv')
df9 = pd.read_csv('../Data/all_speakers_india7.csv')
df10 = pd.read_csv('../Data/all_speakers_india8.csv')
df11 = pd.read_csv('../Data/all_speakers_english1.csv')

# %%
df1.head()
# Out:
#    age  age_onset                   birthplace    filename native_language  \
# 0   22         12       hong kong, china (map)  cantonese1         cantone
# 1   20         13       hong kong, china (map)  cantonese2         cantone
# 2   22          6       hong kong, china (map)  cantonese3         cantone
# 3   29         13  fuzhou, fujian, china (map)  cantonese4         cantone
# 4   18         14       hong kong, china (map)  cantonese5         cantone
#
#        sex  speakerid country  file_missing?
# 0  female          45   china          False
# 1    male          46   china          False
# 2    male          47   china          False
# 3  female          48   china          False
# 4    male          49   china          False

# %%
new_df=pd.concat([new_df, df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11],axis=0)
#new_df=pd.concat([new_df, df1],axis=0)

# %%
new_df.shape
# Out:
# (1659, 9)

# %%
new_df.head()
# Out:
#     age  age_onset                             birthplace   filename  \
# 104  19        9.0             shady grove, maryland, usa   arabic38
# 112  32       12.0            fort collins, colorado, usa   arabic45
# 148  19        3.0  washington, district of columbia, usa   arabic78
# 187  43       40.0               jianchuan, yunnan, china       bai1
# 205  34        3.5           durgapur, west bengal, india  bengali11
#
#     native_language     sex  speakerid country  file_missing?
# 104          arabic  female       1394     usa          False
# 112          arabic  female       1456     usa          False
# 148          arabic  female       1897     usa          False
# 187             bai  female         28   china          False
# 205         bengali    male       1018   india          False

# %%
#Remove duplicatefiles

# %%
new_df[new_df['filename'].duplicated()==True]
# Out:
#     age  age_onset                          birthplace    filename  \
# 0    22       12.0              hong kong, china (map)  cantonese1
# 1    20       13.0              hong kong, china (map)  cantonese2
# 2    22        6.0              hong kong, china (map)  cantonese3
# 3    29       13.0         fuzhou, fujian, china (map)  cantonese4
# 4    18       14.0              hong kong, china (map)  cantonese5
# ..   ..        ...                                 ...         ...
# 571  51        0.0        fort worth, texas, usa (map)  english572
# 572  46        0.0        painesville, ohio, usa (map)  english573
# 574  24        0.0    great falls, virginia, usa (map)  english575
# 575  63        0.0           washington, dc, usa (map)  english576
# 576  38        0.0  san leandro, california, usa (map)  english577
#
#     native_language      sex  speakerid  country  file_missing?
# 0           cantone  female          45    china          False
# 1           cantone    male          46    china          False
# 2           cantone    male          47    china          False
# 3           cantone  female          48    china          False
# 4           cantone    male          49    china          False
# ..              ...      ...        ...      ...            ...
# 571         english    male        2121  usa, uk          False
# 572         english    male        2124      usa          False
# 574         english    male        2165      usa          False
# 575         english  female        2167      usa          False
# 576         english  female        2170      usa          False
#
# [656 rows x 9 columns]

# %%
new_df.drop_duplicates(['filename'],keep='last',inplace=True)

# %%
new_df.shape
# Out:
# (1003, 9)

# %%
new_df[((new_df['native_language']!='english') & (new_df['country']=='usa'))]
# Out:
#      age  age_onset                             birthplace   filename  \
# 104   19        9.0             shady grove, maryland, usa   arabic38
# 112   32       12.0            fort collins, colorado, usa   arabic45
# 148   19        3.0  washington, district of columbia, usa   arabic78
# 958   52        6.0                bethesda, maryland, usa    farsi14
# 999   22        6.0                    washington, dc, usa   french18
# 1110  24        4.0           bethlehem, pennsylvania, usa    greek12
# 1112  22        3.0           lancaster, pennsylvania, usa    greek14
# 1283  19       16.0            new orleans, louisiana, usa   kikongo1
# 1336  26        3.0                 bayside, new york, usa   korean42
# 1722  25        5.0                brooklyn, new york, usa  russian39
# 1917  20        5.0                    miami, florida, usa  spanish72
# 1982  21        6.0              alexandria, virginia, usa  tagalog17
# 2084  19        5.0              woodbridge, virginia, usa       twi5
# 2112  20        5.0              alexandria, virginia, usa      urdu9
# 2162  52        5.0                brooklyn, new york, usa   yiddish3
# 2170  31        1.0                    bethel, alaska, usa     yupik1
#
#      native_language     sex  speakerid country  file_missing?
# 104           arabic  female       1394     usa          False
# 112           arabic  female       1456     usa          False
# 148           arabic  female       1897     usa          False
# 958            farsi  female       1572     usa          False
# 999           french    male        741     usa          False
# 1110           greek    male       1712     usa          False
# 1112           greek  female       1816     usa          False
# 1283         kikongo    male        464     usa          False
# 1336          korean    male       1950     usa          False
# 1722         russian  female       1750     usa          False
# 1917         spanish  female       1238     usa          False
# 1982         tagalog    male       2146     usa          False
# 2084             twi    male       2001     usa          False
# 2112            urdu  female       1539     usa          False
# 2162         yiddish    male       1161     usa          False
# 2170           yupik  female        571     usa          False

# %%
new_df[((new_df['native_language']=='english') & (new_df['country']=='usa')) | (new_df['country']=='china') | (new_df['country']=='india')]
# Out:
#      age  age_onset                           birthplace    filename  \
# 187   43       40.0             jianchuan, yunnan, china        bai1
# 1299  38        6.0     hyderabad, andhra pradesh, india    konkani1
# 1493  21        3.0                        bombay, india    marathi1
# 1494  28       10.0                        madras, india    marathi2
# 1495  31        2.0                        bombay, india    marathi3
# ...   ..        ...                                  ...         ...
# 624   20        0.0    minneapolis, minnesota, usa (map)  english625
# 625   21        0.0          hammond, indiana, usa (map)  english626
# 627   55        0.0  pittsburgh, pennsylvania, usa (map)  english628
# 628   20        0.0    south riding, virginia, usa (map)  english629
# 629   21        0.0      woodbridge, virginia, usa (map)  english630
#
#      native_language      sex  speakerid country  file_missing?
# 187              bai   female         28   china          False
# 1299         konkani   female        438   india          False
# 1493         marathi   female        264   india          False
# 1494         marathi     male        265   india          False
# 1495         marathi     male        837   india          False
# ...              ...      ...        ...     ...            ...
# 624          english    male        2805     usa          False
# 625          english  female        2806     usa          False
# 627          english    male        2855     usa          False
# 628          english  female        2894     usa          False
# 629          english  female        2895     usa          False
#
# [764 rows x 9 columns]

# %%
new_df.to_csv('../Data/File_for_modeling.csv',index=False)
